# %%
import torch  
import torch.nn as nn 
import torchvision
import torch.nn.functional as F
import torch.optim as optim 
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

# %%
#Hyper parameters 
Epoch_num = 100
batch_size =64
learning_rate = 0.01

width = 224
height = 224

device =  torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
training_transfrom = transforms.Compose([transforms.Resize((width,height)), transforms.RandomRotation(30),
                transforms.RandomVerticalFlip(),transforms.RandomHorizontalFlip(), 
                transforms.ToTensor() ,transforms.Normalize([0.485,0.456,0.406],[0.229,0.224,0.225])])

training_data =  datasets.Flowers102(root='data', split='train', download= True, transform= training_transfrom)

training_loader = DataLoader(training_data, batch_size=batch_size, shuffle= True, num_workers=2)

val_transform = transforms.Compose([transforms.Resize((width,height)),transforms.ToTensor(), 
                                    transforms.Normalize([0.485,0.456,0.406],[0.229,0.224,0.225])])
val_data = datasets.Flowers102(root='data', split = 'val', download=True, transform = val_transform)

val_loader = DataLoader(val_data, batch_size= batch_size, shuffle=True)

test_transform = transforms.Compose([transforms.Resize((width,height)), transforms.ToTensor(), 
                                     transforms.Normalize([0.485,0.456,0.406],[0.229,0.224,0.225])])

test_data = datasets.Flowers102(root='data', split = 'test', download = True, transform = test_transform)
test_loader = DataLoader(test_data, batch_size= batch_size, shuffle = True)
# Out:
# Downloading https://thor.robots.ox.ac.uk/datasets/flowers-102/102flowers.tgz to data\flowers-102\102flowers.tgz
# 100%|██████████| 344862509/344862509 [00:56<00:00, 6144598.35it/s]
# Extracting data\flowers-102\102flowers.tgz to data\flowers-102
# Downloading https://thor.robots.ox.ac.uk/datasets/flowers-102/imagelabels.mat to data\flowers-102\imagelabels.mat
# 100%|██████████| 502/502 [00:00<00:00, 503236.28it/s]
# Downloading https://thor.robots.ox.ac.uk/datasets/flowers-102/setid.mat to data\flowers-102\setid.mat
# 100%|██████████| 14989/14989 [00:00<00:00, 7514752.89it/s]

# %%
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=96, kernel_size=(11,11), stride = (4,4), padding=(1,1))
        self.conv2 = nn.Conv2d(in_channels=96, out_channels=256, kernel_size=(5,5), stride = (1,1), padding=(1,1))
        self.conv3 = nn.Conv2d(in_channels=256, out_channels= 384, kernel_size= (3,3), stride=(1,1), padding=(1,1))
        self.conv4 = nn.Conv2d(in_channels = 384, out_channels= 384, kernel_size=(3,3), stride=(1,1), padding=(1,1))
        self.conv5 = nn.Conv2d(in_channels=384, out_channels= 256, kernel_size=(3,3), padding=(1,1))
        self.pool = nn.MaxPool2d(kernel_size= (3,3), stride= (2,2))
        self.fc1 = nn.Linear(256*5*5, 4096)
        self.fc2 = nn.Linear(4096, 4096)
        self.fc3 = nn.Linear(4096, 102)
        self.dropout = nn.Dropout(0.5)
        
    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = self.pool(x)
        # print(x.shape)
        # x = self.dropout(x)
        x = F.relu(self.conv2(x))
        x = self.pool(x)
        # print(x.shape)
        x = F.relu(self.conv3(x))
        # x = self.pool(x)
        # print(x.shape)
        x = F.relu(self.conv4(x))
        # x = self.pool(x)
        x = F.relu(self.conv5(x))
        # print(x.shape)
        x = self.pool(x)
        x = x.view(-1, 256 *5 *5)
        # x = x.view(x.size(0), -1)
        x = self.dropout(x)
        x = self.fc1(x)
        x = self.dropout(x)
        x = self.fc2(x)
        # x = self.fc2(x)
        x = self.fc3(x)
        return x
        


model = CNN().to(device)

optimiser = optim.SGD(model.parameters(),lr=learning_rate, momentum=0.9)

criterion = nn.CrossEntropyLoss()

# scheduler = optim.lr_scheduler.StepLR(optimiser, step_size= 20, gamma=0.75, verbose= True)

# x = torch.randn(0, 3, 240, 240)
# y = model(x)
# print(y.shape)
print(model)
# Out:
# CNN(
#   (conv1): Conv2d(3, 96, kernel_size=(11, 11), stride=(4, 4), padding=(1, 1))
#   (conv2): Conv2d(96, 256, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (conv3): Conv2d(256, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv4): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv5): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=(3, 3), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=6400, out_features=4096, bias=True)
#   (fc2): Linear(in_features=4096, out_features=4096, bias=True)
#   (fc3): Linear(in_features=4096, out_features=102, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
# )

# %%
image, label = next(iter(training_loader))

image = image.to(device)

x = F.relu(model.conv1(image))
x = model.pool(x)
# print(x.shape)
x = F.relu(model.conv2(x))
x = model.pool(x)
# print(x.shape)
x = F.relu(model.conv3(x))
# x = model.pool(x)
# print(x.shape)
x = F.relu(model.conv4(x))
# x = model.pool(x)
x = F.relu(model.conv5(x))
x = model.pool(x)
print(x.shape)
# Out:
# torch.Size([64, 256, 5, 5])

# %%
# train_losses = []
# valid_lossess = []

for epoch in range(Epoch_num):
    train_loss = 0.0
    valid_loss = 0.0
    correct = 0
    total = 0
    best_accuracy = 38

    
    model.train()
    for batch, (data,target) in enumerate(training_loader):
        
        data = data.to(device)
        target = target.to(device)
        
        optimiser.zero_grad()
        out = model(data)
        loss = criterion(out, target)
        loss.backward()
        optimiser.step()
        train_loss += loss.item() * data.size(0)
        
        
    model.eval()
    with torch.no_grad():
      for data, target in val_loader:
        
          data = data.to(device)
          target = target.to(device)
        
          out = model(data)

          _, predicted = torch.max(out.data, 1)

          total += target.size(0)
          correct += (predicted == target).sum().item()
          loss = criterion(out, target)

          valid_loss += loss.item() * data.size(0)
    accuracy = (correct / total) *100
    
    if(accuracy > best_accuracy):
      best_accuracy = accuracy
      torch.save(model, 'model_best')
      
    # if(learning_rate > 0.001):
    #   scheduler.step()
    train_loss = train_loss/len(training_loader.sampler)
    valid_loss = valid_loss/len(val_loader.sampler)
    # train_losses.append(train_loss)
    # valid_lossess.append(valid_loss)
    print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f} \tAccuracy: {:.6f}'.format(epoch, train_loss, valid_loss, accuracy))
    

def final_test(test_loader, model):
  with torch.no_grad():
    correct = 0 
    total = 0
    for data, target in test_loader:
      data = data.to(device)
      target = target.to(device)

      out = model(data)

      _, predicted = torch.max(out.data, 1)

      total += target.size(0)

      correct +=( predicted == target).sum().item()

    accuracy = (correct / total) *100
    print("Accuracy: {:.2f}".format(accuracy))

best_model = torch.load('model_best')
final_test(test_loader, best_model)
# Out:
# Epoch: 0 	Training Loss: 4.626278 	Validation Loss: 4.624261 	Accuracy: 1.568627
# Epoch: 1 	Training Loss: 4.624553 	Validation Loss: 4.622897 	Accuracy: 1.078431
# Epoch: 2 	Training Loss: 4.623551 	Validation Loss: 4.620454 	Accuracy: 2.843137
# Epoch: 3 	Training Loss: 4.620285 	Validation Loss: 4.612362 	Accuracy: 2.450980
# Epoch: 4 	Training Loss: 4.600748 	Validation Loss: 4.550150 	Accuracy: 2.941176
# Epoch: 5 	Training Loss: 4.423779 	Validation Loss: 4.281916 	Accuracy: 3.137255
# Epoch: 6 	Training Loss: 4.323688 	Validation Loss: 4.301372 	Accuracy: 2.843137
# Epoch: 7 	Training Loss: 4.148714 	Validation Loss: 3.999873 	Accuracy: 4.803922
# Epoch: 8 	Training Loss: 4.019516 	Validation Loss: 4.055487 	Accuracy: 5.000000
# Epoch: 9 	Training Loss: 3.951239 	Validation Loss: 3.909985 	Accuracy: 5.882353
# Epoch: 10 	Training Loss: 3.780429 	Validation Loss: 3.845984 	Accuracy: 7.745098
# Epoch: 11 	Training Loss: 3.799098 	Validation Loss: 3.716214 	Accuracy: 8.627451
# Epoch: 12 	Training Loss: 3.762041 	Validation Loss: 3.747763 	Accuracy: 9.705882
# Epoch: 13 	Training Loss: 3.593875 	Validation Loss: 3.629124 	Accuracy: 9.607843
# Epoch: 14 	Training Loss: 3.504168 	Validation Loss: 3.682637 	Accuracy: 8.921569
# Epoch: 15 	Training Loss: 3.415448 	Validation Loss: 3.588162 	Accuracy: 12.352941
# Epoch: 16 	Training Loss: 3.398120 	Validation Loss: 3.523238 	Accuracy: 12.843137
# Epoch: 17 	Training Loss: 3.310869 	Validation Loss: 3.486826 	Accuracy: 13.235294
# Epoch: 18 	Training Loss: 3.268914 	Validation Loss: 3.447644 	Accuracy: 14.901961
# Epoch: 19 	Training Loss: 3.160476 	Validation Loss: 3.409230 	Accuracy: 14.607843
# Epoch: 20 	Training Loss: 3.141162 	Validation Loss: 3.541729 	Accuracy: 12.254902
# Epoch: 21 	Training Loss: 3.177953 	Validation Loss: 3.262969 	Accuracy: 17.843137
# Epoch: 22 	Training Loss: 2.954467 	Validation Loss: 3.192107 	Accuracy: 19.607843
# Epoch: 23 	Training Loss: 2.941780 	Validation Loss: 3.136022 	Accuracy: 20.686275
# Epoch: 24 	Training Loss: 2.795829 	Validation Loss: 3.018536 	Accuracy: 20.686275
# Epoch: 25 	Training Loss: 2.698086 	Validation Loss: 3.128602 	Accuracy: 21.176471
# Epoch: 26 	Training Loss: 2.687033 	Validation Loss: 3.143155 	Accuracy: 22.058824
# Epoch: 27 	Training Loss: 2.749571 	Validation Loss: 3.283756 	Accuracy: 18.039216
# Epoch: 28 	Training Loss: 2.736375 	Validation Loss: 3.123309 	Accuracy: 22.058824
# Epoch: 29 	Training Loss: 2.716445 	Validation Loss: 3.040895 	Accuracy: 24.117647
# Epoch: 30 	Training Loss: 2.438099 	Validation Loss: 3.075032 	Accuracy: 22.156863
# Epoch: 31 	Training Loss: 2.429237 	Validation Loss: 2.948002 	Accuracy: 25.784314
# Epoch: 32 	Training Loss: 2.395451 	Validation Loss: 2.911096 	Accuracy: 26.960784
# Epoch: 33 	Training Loss: 2.300586 	Validation Loss: 2.911826 	Accuracy: 28.725490
# Epoch: 34 	Training Loss: 2.224687 	Validation Loss: 3.041226 	Accuracy: 27.156863
# Epoch: 35 	Training Loss: 2.249987 	Validation Loss: 2.867504 	Accuracy: 28.431373
# Epoch: 36 	Training Loss: 2.126564 	Validation Loss: 3.004401 	Accuracy: 27.352941
# Epoch: 37 	Training Loss: 2.116124 	Validation Loss: 2.859920 	Accuracy: 29.019608
# Epoch: 38 	Training Loss: 1.940836 	Validation Loss: 2.935615 	Accuracy: 30.588235
# Epoch: 39 	Training Loss: 2.029267 	Validation Loss: 2.967110 	Accuracy: 30.098039
# Epoch: 40 	Training Loss: 1.989446 	Validation Loss: 2.993973 	Accuracy: 29.803922
# Epoch: 41 	Training Loss: 1.979652 	Validation Loss: 2.942099 	Accuracy: 29.803922
# Epoch: 42 	Training Loss: 1.921104 	Validation Loss: 2.954869 	Accuracy: 33.039216
# Epoch: 43 	Training Loss: 1.840789 	Validation Loss: 3.046696 	Accuracy: 30.490196
# Epoch: 44 	Training Loss: 1.864417 	Validation Loss: 2.907168 	Accuracy: 32.941176
# Epoch: 45 	Training Loss: 1.629733 	Validation Loss: 2.788620 	Accuracy: 35.392157
# Epoch: 46 	Training Loss: 1.607127 	Validation Loss: 2.991556 	Accuracy: 32.745098
# Epoch: 47 	Training Loss: 1.606073 	Validation Loss: 2.808104 	Accuracy: 33.431373
# Epoch: 48 	Training Loss: 1.497556 	Validation Loss: 3.044792 	Accuracy: 33.137255
# Epoch: 49 	Training Loss: 1.468855 	Validation Loss: 2.966488 	Accuracy: 32.941176
# Epoch: 50 	Training Loss: 1.606552 	Validation Loss: 3.110607 	Accuracy: 32.843137
# Epoch: 51 	Training Loss: 1.553841 	Validation Loss: 3.094065 	Accuracy: 31.176471
# Epoch: 52 	Training Loss: 1.519934 	Validation Loss: 2.909762 	Accuracy: 34.607843
# Epoch: 53 	Training Loss: 1.465857 	Validation Loss: 3.096304 	Accuracy: 35.686275
# Epoch: 54 	Training Loss: 1.408467 	Validation Loss: 3.000423 	Accuracy: 31.764706
# Epoch: 55 	Training Loss: 1.409384 	Validation Loss: 3.241055 	Accuracy: 35.294118
# Epoch: 56 	Training Loss: 1.377447 	Validation Loss: 3.060215 	Accuracy: 35.686275
# Epoch: 57 	Training Loss: 1.252684 	Validation Loss: 3.003990 	Accuracy: 37.156863
# Epoch: 58 	Training Loss: 1.232037 	Validation Loss: 3.001671 	Accuracy: 37.843137
# Epoch: 59 	Training Loss: 1.384945 	Validation Loss: 3.147232 	Accuracy: 35.588235
# Epoch: 60 	Training Loss: 1.315816 	Validation Loss: 3.177867 	Accuracy: 34.117647
# Epoch: 61 	Training Loss: 1.102845 	Validation Loss: 3.346766 	Accuracy: 36.176471
# Epoch: 62 	Training Loss: 1.056158 	Validation Loss: 3.384147 	Accuracy: 35.392157
# Epoch: 63 	Training Loss: 1.006726 	Validation Loss: 3.188478 	Accuracy: 37.156863
# Epoch: 64 	Training Loss: 1.045633 	Validation Loss: 3.319975 	Accuracy: 38.235294
# Epoch: 65 	Training Loss: 1.063062 	Validation Loss: 3.121544 	Accuracy: 38.235294
# Epoch: 66 	Training Loss: 1.015997 	Validation Loss: 3.119113 	Accuracy: 39.607843
# Epoch: 67 	Training Loss: 0.913679 	Validation Loss: 3.558840 	Accuracy: 35.294118
# Epoch: 68 	Training Loss: 1.082262 	Validation Loss: 3.116503 	Accuracy: 38.333333
# Epoch: 69 	Training Loss: 1.151484 	Validation Loss: 3.166749 	Accuracy: 36.176471
# Epoch: 70 	Training Loss: 1.069113 	Validation Loss: 3.432776 	Accuracy: 35.000000
# Epoch: 71 	Training Loss: 0.881631 	Validation Loss: 3.528446 	Accuracy: 36.666667
# Epoch: 72 	Training Loss: 0.934585 	Validation Loss: 3.345032 	Accuracy: 36.568627
# Epoch: 73 	Training Loss: 0.988677 	Validation Loss: 3.039861 	Accuracy: 36.176471
# Epoch: 74 	Training Loss: 0.916009 	Validation Loss: 3.205193 	Accuracy: 38.725490
# Epoch: 75 	Training Loss: 0.976302 	Validation Loss: 3.214765 	Accuracy: 37.745098
# Epoch: 76 	Training Loss: 0.914831 	Validation Loss: 3.284024 	Accuracy: 39.411765
# Epoch: 77 	Training Loss: 0.841992 	Validation Loss: 3.415606 	Accuracy: 38.235294
# Epoch: 78 	Training Loss: 0.863255 	Validation Loss: 3.382393 	Accuracy: 37.450980
# Epoch: 79 	Training Loss: 1.004389 	Validation Loss: 3.447132 	Accuracy: 35.588235
# Epoch: 80 	Training Loss: 1.023374 	Validation Loss: 3.619338 	Accuracy: 34.803922
# Epoch: 81 	Training Loss: 0.796110 	Validation Loss: 3.427937 	Accuracy: 36.960784
# Epoch: 82 	Training Loss: 0.941551 	Validation Loss: 3.533796 	Accuracy: 39.215686
# Epoch: 83 	Training Loss: 0.748464 	Validation Loss: 3.574705 	Accuracy: 40.098039
# Epoch: 84 	Training Loss: 0.897158 	Validation Loss: 3.401818 	Accuracy: 40.490196
# Epoch: 85 	Training Loss: 0.784729 	Validation Loss: 3.388560 	Accuracy: 40.980392
# Epoch: 86 	Training Loss: 0.677836 	Validation Loss: 3.483321 	Accuracy: 40.490196
# Epoch: 87 	Training Loss: 0.810267 	Validation Loss: 3.399681 	Accuracy: 40.490196
# Epoch: 88 	Training Loss: 0.881128 	Validation Loss: 3.594863 	Accuracy: 39.215686
# Epoch: 89 	Training Loss: 0.815035 	Validation Loss: 3.343638 	Accuracy: 42.745098
# Epoch: 90 	Training Loss: 0.829479 	Validation Loss: 3.435328 	Accuracy: 39.117647
# Epoch: 91 	Training Loss: 0.796543 	Validation Loss: 3.445567 	Accuracy: 41.372549
# Epoch: 92 	Training Loss: 0.666827 	Validation Loss: 3.756485 	Accuracy: 39.509804
# Epoch: 93 	Training Loss: 0.755822 	Validation Loss: 3.393040 	Accuracy: 40.490196
# Epoch: 94 	Training Loss: 0.687148 	Validation Loss: 3.973927 	Accuracy: 40.294118
# Epoch: 95 	Training Loss: 0.714090 	Validation Loss: 3.718394 	Accuracy: 37.450980
# Epoch: 96 	Training Loss: 0.665571 	Validation Loss: 4.107388 	Accuracy: 37.843137
# Epoch: 97 	Training Loss: 0.632866 	Validation Loss: 3.579352 	Accuracy: 40.098039
# Epoch: 98 	Training Loss: 0.638299 	Validation Loss: 3.709809 	Accuracy: 40.784314
# Epoch: 99 	Training Loss: 0.689697 	Validation Loss: 3.596564 	Accuracy: 40.196078
# Accuracy: 35.88

# %%
best_model = torch.load('best_trained_model')
final_test(test_loader,best_model)
# Out:
# Accuracy: 35.88
